# %%
import numpy as np

# %%
def __init__(self):
    pass

def train(self, X, y):
    self.Xtr = X
    self.Ytr = y

def predict(self, X):
    num_test = X.shape[0]
    Ypred = np.zeroes(num_test, dtype = ytr.dtype)

    for i in xrange(num_test):
        distances = np.sum(np.abs(self.Xtr - X[i, :]), axis=1)
        min_distance = np.argmin(distances)
        Ypred[i] = self.ytr[min_distance]

    return Ypred
